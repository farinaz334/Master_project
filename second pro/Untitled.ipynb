# %%
df.columns[1]
# Out:
# 'Total business\nnumbers'

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv ("../project test1/Table9.csv",encoding='ISO-8859-1')
df
# Out:
#            ï»¿Region/country  Total business\nnumbers  \
# 0             United Kingdom                  5555130
# 1                 North East                   156425
# 2                 North West                   545150
# 3   Yorkshire and the Humber                   389165
# 4              East Midlands                   382000
# 5              West Midlands                   448240
# 6            East of England                   569180
# 7                     London                  1049405
# 8                 South East                   852210
# 9                 South West                   524005
# 10                   England                  4915780
# 11                     Wales                   218995
# 12                  Scotland                   298255
# 13          Northern Ireland                   122095
#
#     Total employment\n(thousands) [Note 5]  \
# 0                                    27524
# 1                                      741
# ...

# %%
#percentage:
df_array = df.to_numpy()

df_array[4]=np.multiply(df_array[4], df_array[1] * 0.01)
df_array[5]=np.multiply(df_array[5], df_array[1] * 0.01)
df_array[6]=np.multiply(df_array[6], df_array[1] * 0.01)
df_array[7]=np.multiply(df_array[7], df_array[1] * 0.01)


df_array[8]=np.multiply(df[8], df_array[2] * 0.01)
df_array[9]=np.multiply(df[9], df_array[2] * 0.01)
df_array[10]=np.multiply(df[10], df_array[2] * 0.01)
df_array[11]=np.multiply(df[11], df_array[2] * 0.01)


df_array[12]=np.multiply(df_array[12], df_array[3] * 0.01)
df_array[13]=np.multiply(df_array[13], df_array[3] * 0.01)
df_array[14]=np.multiply(df_array[14], df_array[3] * 0.01)
df_array[15]=np.multiply(df_array[15], df_array[3] * 0.01)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 4
#       1 #percentage:
#       2 df_array = df.to_numpy()
# ----> 4 df_array[4]=np.multiply(df_array[4], df_array[1] * 0.01)
#       5 df_array[5]=np.multiply(df_array[5], df_array[1] * 0.01)
#       6 df_array[6]=np.multiply(df_array[6], df_array[1] * 0.01)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
pd.options.display.float_format = '{:.2f}'.format

# Display the modified DataFrame
print(df)
# Out:
#            ï»¿Region/country  Total business\nnumbers  \
# 0             United Kingdom                  5555130
# 1                 North East                   156425
# 2                 North West                   545150
# 3   Yorkshire and the Humber                   389165
# 4              East Midlands                   382000
# 5              West Midlands                   448240
# 6            East of England                   569180
# 7                     London                  1049405
# 8                 South East                   852210
# 9                 South West                   524005
# 10                   England                  4915780
# 11                     Wales                   218995
# 12                  Scotland                   298255
# 13          Northern Ireland                   122095
#
#     Total employment\n(thousands) [Note 5]  \
# 0                                    27524
# 1                                      741
# ...
